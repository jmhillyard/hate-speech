# %% [markdown]
# ## this removed special chars urls etc .. and randomly samples the larger file

# %%
import numpy as np
import random
import string
import re
from nltk.corpus import wordnet

# %%
pwd
# Out:
# u'/Users/janehillyard/Documents/capstone/hate-speech/data'

# %%
with open("fulltest.txt", "rb") as source:
    lines = [line for line in source]

# %% [markdown]
# ##  and randomly samples the larger file

# %%
rand_smpl = [ lines[i] for i in sorted(random.sample(xrange(len(lines)), 10)) ]
with open("parttest.txt", "wb") as wr:
    wr.write("".join(rand_smpl))
    
with open("parttest.txt", "rb") as source:
    lines = [line for line in source]
len(lines) 
# with open("parttest2.txt", "w") as text_file:
#     text_file.write(random_choice)
# Out:
# 10

# %%
print lines
# Out:
# ["0 @fictillius  Yeah...  But  $5.99...    I'd  rather  use  Tweetie!  ($3.99)\n", "0 I  just  got  the  greatest  header  idea!  Too  bad  I  don't  have  a  Photoshop  \n", "0 My  manager  is  yelling  at  me  for  twittering  at  work...i'm  about  to  get  my  phone  taken  away!!  \n", '0 @nikkibop  all  my  memo  padfiles  were  deleted.  I  been  working  on  this  next  chapter  for  three  days  to  make  it  perfect!!!    gone!\n', '0 tomorrow  is  the  1st  day  of  or  last  year  in  high  school  ahhmmppp....  \n', "0 @Kate_Smash  I  am  ashamed  as  well,  but  considering  what  happened  here  in  '00,  I'm  not  terribly  surprised.  \n", "1 @Wil_Anderson    and  THAT'S  no  slur!  \n", '1 @rockeye  I  might  give  it  another  go.  \n', '1 @GennaGirl  ugh  worst  part  of  being  a  big  sissy.....you  cry  all  the  time    and  are  constantly  proud!\n', "1 had  a  great  day  with  my  two  papi's.  \n"]

# %%
def clean_data(X):
    # Function: lowercase (also completed in vecorizer),
    #           remove special characters, remove numbers
    # Input: numpy array of strings of text
    # Output:  numpy string of cleansed text
    #text = [re.sub(r'[^\w\s\d]','',h.lower()) for h in X]
    l=[]
    w=[]
    l2=[]
    regex = re.compile('[^a-zA-Z0-9]')
    for i in X:
        text = " ".join(filter(lambda x:x[0]!='@', i.split()))
        text = re.sub(r'\w+:\/{2}[\d\w-]+(\.[\d\w-]+)*(?:(?:\/[^\s/]*))*', '', text)
        text = re.sub(r'[^\w\s\d]','',text.lower())
        l.append(regex.sub(' ', str(text)))
        line = str(l)
        l=[]
        for word in line.split():
            if wordnet.synsets(word):
                l.append(word)
        l2.append(' '.join(l))
    return np.array(l2)

# %%
x = clean_data(lines)
len(x)
x
# Out:
# array(['yeah but id rather use',
#        'i just got greatest header idea too bad i have a',
#        'manager is yelling at me twittering at about get phone taken',
#        'all memo were deleted i been working on next chapter three days make it perfect',
#        'tomorrow is 1st day or last year in high school',
#        'i am ashamed as well but considering happened here in not terribly',
#        'no', 'i might give it another',
#        'worst part being a big cry all time are constantly',
#        'had a great day two'],
#       dtype='|S79')

# %%
l=[]
w=[]
regex = re.compile('[^a-zA-Z]0-9')
for i in lines:
    #text = " ".join(filter(lambda x:x[0]!='@', i.split()))

    text = re.sub(r'\w+:\/{2}[\d\w-]+(\.[\d\w-]+)*(?:(?:\/[^\s/]*))*', '', text)
    text = re.sub(r'[^\w\s\d]','',text.lower())
    l.append(regex.sub(' ', str(text)))
    line = str(l)
    l=[]
    for word in line.split():
        if wordnet.synsets(word):
            l.append(word)
    print 'print i',l
    l2.append(' '.join(l))
    print 'print i',l2
#print np.array(l2)

# %%
from nltk.corpus import wordnet
l2=[]
for i in x:
    l=[]
    print type(i)
    l.append for word in i.split():
        if wordnet.synsets(word):
            l.append(word)
    l2.append(' '.join(l))
print len(l2)
# Out:
# <type 'numpy.string_'>
# <type 'numpy.string_'>
# <type 'numpy.string_'>
# <type 'numpy.string_'>
# <type 'numpy.string_'>
# <type 'numpy.string_'>
# <type 'numpy.string_'>
# <type 'numpy.string_'>
# <type 'numpy.string_'>
# <type 'numpy.string_'>
# <type 'numpy.string_'>
# <type 'numpy.string_'>
# <type 'numpy.string_'>
# <type 'numpy.string_'>
# <type 'numpy.string_'>
# <type 'numpy.string_'>
# <type 'numpy.string_'>
# <type 'numpy.string_'>
# <type 'numpy.string_'>
# <type 'numpy.string_'>
# <type 'numpy.string_'>
# <type 'numpy.string_'>
# <type 'numpy.string_'>
# <type 'numpy.string_'>
# <type 'numpy.string_'>
# <type 'numpy.string_'>
# <type 'numpy.string_'>
# <type 'numpy.string_'>
# <type 'numpy.string_'>
# <type 'numpy.string_'>
# <type 'numpy.string_'>
# <type 'numpy.string_'>
# <type 'numpy.string_'>
# <type 'numpy.string_'>
# <type 'numpy.string_'>
# <type 'numpy.string_'>
# <type 'numpy.string_'>
# <type 'numpy.string_'>
# <type 'numpy.string_'>
# <type 'numpy.string_'>
# ...

# %%
l2[0:2]
# Out:
# ['0 i fell tired i want sleep but almost done some work i need go bathroom',
#  '0 i fell tired i want sleep but almost done some work i need go bathroom 0 was going do resin but then a friend popped over a cold now time bread']

# %%
with open("parttest.txt", "wb") as wr:
    wr.write("".join(rand_smpl))
    
with open("parttest.txt", "rb") as source:
    lines = [line for line in source]
   
# with open("parttest2.txt", "w") as text_file:
#     text_file.write(random_choice)

# %%
lines[0:10]
# Out:
# ['1 dudeee i LOVED brokeback mountain!!!!\n',
#  '1 Brokeback mountain was beautiful...\n',
#  '0 I hate Harry Potter..\n',
#  '0 @DonnieWahlberg  I  hope  i  can  make  it  to  the  auburn  show.  but  its  not  looking  good  for  me  \n',
#  "0 doesn't  enjoy  learning  CSS.  \n",
#  "0 @reznik360  @bonbonfire  another  fun  confab,  no  matter  what  comes  of  it.  i  wish  i  hadn't  worked  until  9.  i'm  gonna  miss  next  week,  though.  \n",
#  '0 About  to  ge  ready  for  work  as  i  have  a  9  hour  shift  ahead  of  me    x\n',
#  '0 Pure  hurt  my  neck  at  the  gym  \n',
#  '0 @marpagan  what  happened?  \n',
#  '0 @colettebennett  ouch,  a  wedding  in  the  morning    ?\n']

# %%
clean_data(rand_smpl[900:910])
# Out:
# array(['1  hey get in touch with meneed to ask you about something',
#        '1 i went to church today for a weddingand i didnt melt',
#        '1 i know that ryan madson on the phillies isuhmhawt',
#        '1 leaving as boy and coming back as a man',
#        '1 gotta find the hole first came home from the store to find all the water runnin out of it ebaby',
#        '1 off to bowl with some friends',
#        '1 i dont ever quit i get that from my mom wow this is a really fancy parking job',
#        '1 glad you made it there safely', '1 up in la center happy',
#        '1 im still waiting for you to come out with that magic talent serum'],
#       dtype='|S97')

# %%
with open("parttest.txt", "rb") as source:
    lines = [line for line in source]
    
[word for word in lines.split() if word.startswith('$')]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-ac4141887862> in <module>()
#       2     lines = [line for line in source]
#       3
# ----> 4 [word for word in lines.split() if word.startswith('$')]
#
# AttributeError: 'list' object has no attribute 'split'

# %%
len(lines)
#print [word for word in i.split() if word.startswith('$')]
# Out:
# 1999

# %%
lines
# Out:
# ['\n',
#  '\n',
#  '\n',
#  '\n',
#  "0 I'm  working  a  split  shift  tonight      Open  and  close!\n",
#  '\n',
#  '\n',
#  '\n',
#  '0 @missgiggly  Jealous!  Scalp  massages  are  the  best.  And  hand,  and  feet...  I  want  a  massage  now  \n',
#  '\n',
#  '1 Ho  ho  ho    &quot;Deleted  Tweets  found  living  in  the  hereafter.  Web  2.0  -  Where  blunders  never  die&quot;  http://digbig.com/4ytnd  (via  @ElReg)\n',
#  '\n',
#  "0 @catatonique  RUDITY!  I'm  telling  \n",
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '1 @waysideviolet  Ah,  too  bad!  Maybe  next  time!    Have  a  great  evening\n',
#  '\n',
#  '0 stressed  \n',
#  '\n',
#  '\n',
#  '\n',
#  "1 My  roomie  is  back      We're  buying  a  pool  tomorrow!!!  And  I  still  need  a  job..  lame!  Don't  Graduate!  It  sucks!\n",
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '1 going  to  southold  after  lacrosse  practicee  \n',
#  '\n',
#  '\n',
# ...
